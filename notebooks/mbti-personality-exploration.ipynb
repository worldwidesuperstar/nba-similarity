# %%
# Test additional NBA API endpoints for MBTI data
from nba_api.stats.endpoints import playerdashptshots, synergyplaytypes, playerestimatedmetrics
import pandas as pd

# Test player: Stephen Curry
test_player_id = 201939
seasons_to_test = ['2024-25', '2018-19', '2013-14']

print("Testing NBA API endpoints for MBTI data...")
print(f"Player ID: {test_player_id} (Stephen Curry)")
print("-" * 50)

# Test 3: PlayerEstimatedMetrics (Advanced Tracking)
print("\\n3. Testing PlayerEstimatedMetrics endpoint...")

for season in seasons_to_test:
    try:
        estimated = playerestimatedmetrics.PlayerEstimatedMetrics(
            season=season,
            season_type='Regular Season'
        )
        
        dataframes = estimated.get_data_frames()
        print(f"  {season}: SUCCESS - {len(dataframes)} dataframes")
        
        if len(dataframes) > 0:
            df = dataframes[0]
            print(f"    Shape: {df.shape} - Columns: {list(df.columns[:5])}...")
            
            # Check if Curry is in the data
            if 'PLAYER_NAME' in df.columns:
                curry_data = df[df['PLAYER_NAME'].str.contains('Curry', case=False, na=False)]
                print(f"    Curry found: {len(curry_data)} rows")
                
    except Exception as e:
        print(f"  {season}: ERROR - {str(e)[:100]}...")
# Out:
# Testing NBA API endpoints for MBTI data...
# Player ID: 201939 (Stephen Curry)
# --------------------------------------------------
# \n3. Testing PlayerEstimatedMetrics endpoint...
#   2024-25: SUCCESS - 1 dataframes
#     Shape: (569, 32) - Columns: ['PLAYER_ID', 'PLAYER_NAME', 'GP', 'W', 'L']...
#     Curry found: 2 rows
#   2018-19: SUCCESS - 1 dataframes
#     Shape: (530, 32) - Columns: ['PLAYER_ID', 'PLAYER_NAME', 'GP', 'W', 'L']...
#     Curry found: 2 rows
#   2013-14: SUCCESS - 1 dataframes
#     Shape: (482, 32) - Columns: ['PLAYER_ID', 'PLAYER_NAME', 'GP', 'W', 'L']...
#     Curry found: 2 rows

# %%
# Print detailed data from working endpoints
print("\n" + "="*60)
print("DETAILED DATA EXAMINATION")
print("="*60)

# Test just 2024-25 season for detailed output
test_season = '2024-25'
# Out:
# ============================================================
# DETAILED DATA EXAMINATION
# ============================================================

# %%
# Examine PlayerDashPtShots data in detail
print("\n1. SHOT TRACKING DATA (PlayerDashPtShots)")
print("-" * 50)

try:

    curry_team_id = 1610612744

    shots_tracking = playerdashptshots.PlayerDashPtShots(
        player_id=test_player_id,
        team_id=curry_team_id,
        season=test_season,
        season_type_all_star='Regular Season'
    )
    
    dataframes = shots_tracking.get_data_frames()
    print(f"Found {len(dataframes)} dataframes")
    
    for i, df in enumerate(dataframes):
        print(f"\nDataframe {i} - Shape: {df.shape}")
        print(f"Columns: {list(df.columns)}")
        
        if not df.empty:
            print("Sample data:")
            print(df.head(2))
            
            # Look for MBTI-relevant columns
            mbti_cols = [col for col in df.columns if any(keyword in col.upper() for keyword in 
                        ['DEFENDER', 'DRIBBLE', 'TOUCH', 'CLOSE', 'DISTANCE', 'CONTESTED'])]
            if mbti_cols:
                print(f"\nMBTI-relevant columns: {mbti_cols}")
        else:
            print("Empty dataframe")
            
except Exception as e:
    print(f"ERROR: {e}")
# Out:
# 1. SHOT TRACKING DATA (PlayerDashPtShots)
# --------------------------------------------------
# Found 7 dataframes
#
# Dataframe 0 - Shape: (1, 19)
# Columns: ['PLAYER_ID', 'PLAYER_NAME_LAST_FIRST', 'SORT_ORDER', 'GP', 'G', 'SHOT_TYPE', 'FGA_FREQUENCY', 'FGM', 'FGA', 'FG_PCT', 'EFG_PCT', 'FG2A_FREQUENCY', 'FG2M', 'FG2A', 'FG2_PCT', 'FG3A_FREQUENCY', 'FG3M', 'FG3A', 'FG3_PCT']
# Sample data:
#    PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER  GP   G SHOT_TYPE  \
# 0     201939         Curry, Stephen           1  70  70   Overall
#
#    FGA_FREQUENCY  FGM   FGA  FG_PCT  EFG_PCT  FG2A_FREQUENCY  FG2M  FG2A  \
# 0            1.0  564  1257   0.449    0.572           0.377   253   474
#
#    FG2_PCT  FG3A_FREQUENCY  FG3M  FG3A  FG3_PCT
# 0    0.534           0.623   311   783    0.397
#
# Dataframe 1 - Shape: (4, 19)
# Columns: ['PLAYER_ID', 'PLAYER_NAME_LAST_FIRST', 'SORT_ORDER', 'GP', 'G', 'SHOT_TYPE', 'FGA_FREQUENCY', 'FGM', 'FGA', 'FG_PCT', 'EFG_PCT', 'FG2A_FREQUENCY', 'FG2M', 'FG2A', 'FG2_PCT', 'FG3A_FREQUENCY', 'FG3M', 'FG3A', 'FG3_PCT']
# Sample data:
#    PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER  GP   G        SHOT_TYPE  \
# 0     201939         Curry, Stephen           1  70  69  Catch and Shoot
# 1     201939         Curry, Stephen           2  70  70         Pull Ups
#
#    FGA_FREQUENCY  FGM  FGA  FG_PCT  EFG_PCT  FG2A_FREQUENCY  FG2M  FG2A  \
# 0          0.294  161  369   0.436    0.645           0.010     7    13
# 1          0.452  227  568   0.400    0.536           0.115    72   144
#
#    FG2_PCT  FG3A_FREQUENCY  FG3M  FG3A  FG3_PCT
# 0    0.538           0.283   154   356    0.433
# 1    0.500           0.337   155   424    0.366
#
# Dataframe 2 - Shape: (6, 19)
# Columns: ['PLAYER_ID', 'PLAYER_NAME_LAST_FIRST', 'SORT_ORDER', 'GP', 'G', 'SHOT_CLOCK_RANGE', 'FGA_FREQUENCY', 'FGM', 'FGA', 'FG_PCT', 'EFG_PCT', 'FG2A_FREQUENCY', 'FG2M', 'FG2A', 'FG2_PCT', 'FG3A_FREQUENCY', 'FG3M', 'FG3A', 'FG3_PCT']
# Sample data:
#    PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER  GP   G  SHOT_CLOCK_RANGE  \
# 0     201939         Curry, Stephen           1  70   9             24-22
# 1     201939         Curry, Stephen           2  70  64  22-18 Very Early
#
#    FGA_FREQUENCY  FGM  FGA  FG_PCT  EFG_PCT  FG2A_FREQUENCY  FG2M  FG2A  \
# 0          0.008    4   10    0.40    0.450           0.004     3     5
# 1          0.149   86  187    0.46    0.578           0.054    42    68
#
#    FG2_PCT  FG3A_FREQUENCY  FG3M  FG3A  FG3_PCT
# 0    0.600           0.004     1     5     0.20
# 1    0.618           0.095    44   119     0.37
#
# Dataframe 3 - Shape: (5, 19)
# Columns: ['PLAYER_ID', 'PLAYER_NAME_LAST_FIRST', 'SORT_ORDER', 'GP', 'G', 'DRIBBLE_RANGE', 'FGA_FREQUENCY', 'FGM', 'FGA', 'FG_PCT', 'EFG_PCT', 'FG2A_FREQUENCY', 'FG2M', 'FG2A', 'FG2_PCT', 'FG3A_FREQUENCY', 'FG3M', 'FG3A', 'FG3_PCT']
# Sample data:
#    PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER  GP   G DRIBBLE_RANGE  \
# 0     201939         Curry, Stephen           1  70  70    0 Dribbles
# 1     201939         Curry, Stephen           2  70  60     1 Dribble
#
#    FGA_FREQUENCY  FGM  FGA  FG_PCT  EFG_PCT  FG2A_FREQUENCY  FG2M  FG2A  \
# 0          0.353  214  444   0.482    0.658           0.068    58    85
# 1          0.114   71  143   0.497    0.661           0.036    24    45
#
#    FG2_PCT  FG3A_FREQUENCY  FG3M  FG3A  FG3_PCT
# 0    0.682           0.286   156   359    0.435
# 1    0.533           0.078    47    98    0.480
#
# MBTI-relevant columns: ['DRIBBLE_RANGE']
#
# Dataframe 4 - Shape: (4, 19)
# Columns: ['PLAYER_ID', 'PLAYER_NAME_LAST_FIRST', 'SORT_ORDER', 'GP', 'G', 'CLOSE_DEF_DIST_RANGE', 'FGA_FREQUENCY', 'FGM', 'FGA', 'FG_PCT', 'EFG_PCT', 'FG2A_FREQUENCY', 'FG2M', 'FG2A', 'FG2_PCT', 'FG3A_FREQUENCY', 'FG3M', 'FG3A', 'FG3_PCT']
# Sample data:
#    PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER  GP   G  \
# 0     201939         Curry, Stephen           1  70  38
# 1     201939         Curry, Stephen           2  70  70
#
#     CLOSE_DEF_DIST_RANGE  FGA_FREQUENCY  FGM  FGA  FG_PCT  EFG_PCT  \
# 0  0-2 Feet - Very Tight          0.045   29   57   0.509    0.535
# 1       2-4 Feet - Tight          0.338  184  425   0.433    0.496
#
#    FG2A_FREQUENCY  FG2M  FG2A  FG2_PCT  FG3A_FREQUENCY  FG3M  FG3A  FG3_PCT
# 0           0.041    26    51    0.510           0.005     3     6    0.500
# 1           0.217   130   273    0.476           0.121    54   152    0.355
#
# MBTI-relevant columns: ['CLOSE_DEF_DIST_RANGE']
#
# Dataframe 5 - Shape: (4, 19)
# Columns: ['PLAYER_ID', 'PLAYER_NAME_LAST_FIRST', 'SORT_ORDER', 'GP', 'G', 'CLOSE_DEF_DIST_RANGE', 'FGA_FREQUENCY', 'FGM', 'FGA', 'FG_PCT', 'EFG_PCT', 'FG2A_FREQUENCY', 'FG2M', 'FG2A', 'FG2_PCT', 'FG3A_FREQUENCY', 'FG3M', 'FG3A', 'FG3_PCT']
# Sample data:
#    PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER  GP   G  \
# 0     201939         Curry, Stephen           1  70  14
# 1     201939         Curry, Stephen           2  70  63
#
#     CLOSE_DEF_DIST_RANGE  FGA_FREQUENCY  FGM  FGA  FG_PCT  EFG_PCT  \
# 0  0-2 Feet - Very Tight          0.014    8   17   0.471    0.559
# 1       2-4 Feet - Tight          0.160   75  201   0.373    0.507
#
#    FG2A_FREQUENCY  FG2M  FG2A  FG2_PCT  FG3A_FREQUENCY  FG3M  FG3A  FG3_PCT
# 0           0.009     5    11    0.455           0.005     3     6    0.500
# 1           0.039    21    49    0.429           0.121    54   152    0.355
#
# MBTI-relevant columns: ['CLOSE_DEF_DIST_RANGE']
#
# Dataframe 6 - Shape: (3, 19)
# Columns: ['PLAYER_ID', 'PLAYER_NAME_LAST_FIRST', 'SORT_ORDER', 'GP', 'G', 'TOUCH_TIME_RANGE', 'FGA_FREQUENCY', 'FGM', 'FGA', 'FG_PCT', 'EFG_PCT', 'FG2A_FREQUENCY', 'FG2M', 'FG2A', 'FG2_PCT', 'FG3A_FREQUENCY', 'FG3M', 'FG3A', 'FG3_PCT']
# Sample data:
#    PLAYER_ID PLAYER_NAME_LAST_FIRST  SORT_ORDER  GP   G   TOUCH_TIME_RANGE  \
# 0     201939         Curry, Stephen           1  70  70  Touch < 2 Seconds
# 1     201939         Curry, Stephen           2  70  70  Touch 2-6 Seconds
#
#    FGA_FREQUENCY  FGM  FGA  FG_PCT  EFG_PCT  FG2A_FREQUENCY  FG2M  FG2A  \
# 0          0.449  279  564   0.495    0.671           0.098    80   123
# 1          0.288  169  362   0.467    0.552           0.155   107   195
#
#    FG2_PCT  FG3A_FREQUENCY  FG3M  FG3A  FG3_PCT
# 0    0.650           0.351   199   441    0.451
# 1    0.549           0.133    62   167    0.371
#
# MBTI-relevant columns: ['TOUCH_TIME_RANGE']
